# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
X1= ['tom', 'krish', 'nick', 'juli']

X2 = [25, 30, 26, 22]

Result = list(zip(X1,X2))

Result
# Out:
# [('tom', 25), ('krish', 30), ('nick', 26), ('juli', 22)]

# %%
df = pd.read_csv('oil_consumption_per_cap.csv')
df
# Out:
#            country    1965    1966   1967   1968   1969   1970   1971   1972  \
# 0          Algeria  0.1020  0.1300  0.118  0.122  0.125  0.140  0.153  0.163
# 1        Argentina  0.9900  1.0100  1.020  1.020  1.050  0.923  0.969  0.954
# 2        Australia  1.3300  1.5500  1.650  1.750  1.760  1.900  1.960  1.970
# 3          Austria  0.7610  0.8320  0.880  1.010  1.110  1.210  1.350  1.450
# 4       Azerbaijan     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..             ...     ...     ...    ...    ...    ...    ...    ...    ...
# 60  United Kingdom  1.3800  1.4700  1.570  1.650  1.770  1.870  1.870  1.980
# 61   United States  2.7600  2.8700  2.950  3.120  3.270  3.370  3.450  3.700
# 62      Uzbekistan     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 63       Venezuela  0.9730  0.9210  0.906  0.956  0.914  0.927  0.906  0.961
# 64         Vietnam  0.0392  0.0833  0.119  0.118  0.139  0.140  0.116  0.117
#
# ...

# %%
df.iloc[:3 , 1:]
# Out:
#     1965  1966   1967   1968   1969   1970   1971   1972   1973   1974  ...  \
# 0  0.102  0.13  0.118  0.122  0.125  0.140  0.153  0.163  0.173  0.187  ...
# 1  0.990  1.01  1.020  1.020  1.050  0.923  0.969  0.954  0.939  0.930  ...
# 2  1.330  1.55  1.650  1.750  1.760  1.900  1.960  1.970  2.070  2.160  ...
#
#     2007   2008   2009   2010   2011   2012   2013   2014   2015   2016
# 0  0.376  0.402  0.419  0.411  0.430  0.448  0.458  0.452  0.488  0.465
# 1  0.605  0.616  0.596  0.681  0.679  0.703  0.749  0.729  0.741  0.728
# 2  2.030  2.020  2.000  1.980  2.060  2.100  2.080  2.050  2.010  1.980
#
# [3 rows x 52 columns]

# %%
df.loc[df['1965']>1]
# Out:
#                 country   1965   1966  1967  1968  1969  1970  1971  1972  \
# 2             Australia   1.33   1.55  1.65  1.75  1.76  1.90  1.96  1.97
# 7               Belgium   1.69   1.71  1.88  2.18  2.51  2.72  2.78  3.00
# 10               Canada   2.73   2.83  2.97  3.11  3.18  3.34  3.37  3.49
# 15              Denmark   2.19   2.47  2.60  2.80  3.35  3.71  3.63  3.82
# 18              Finland   1.25   1.51  1.58  1.79  2.08  2.33  2.41  2.55
# 19               France   1.10   1.17  1.33  1.43  1.64  1.85  2.00  2.21
# 20              Germany   1.13   1.26  1.29  1.44  1.61  1.77  1.83  1.93
# 27               Israel   1.54   1.56  1.59  1.62  1.65  1.68  1.70  1.72
# 28                Italy   1.01   1.11  1.21  1.33  1.45  1.63  1.74  1.81
# 31               Kuwait  11.50  10.10  8.99  8.01  7.20  6.52  6.01  6.13
# 35          Netherlands   2.06   2.21  2.23  2.37  2.56  2.81  2.74  3.01
# 36          New Zealand   1.03   1.13  1.17  1.19  1.22  1.41  1.43  1.51
# ...

# %%
df.where(df['1965']>1)
# Out:
#            country  1965  1966  1967  1968  1969  1970  1971  1972  1973  ...  \
# 0              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2        Australia  1.33  1.55  1.65  1.75  1.76  1.90  1.96  1.97  2.07  ...
# 3              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 60  United Kingdom  1.38  1.47  1.57  1.65  1.77  1.87  1.87  1.98  2.03  ...
# 61   United States  2.76  2.87  2.95  3.12  3.27  3.37  3.45  3.70  3.87  ...
# 62             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 63             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 64             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
# ...
