# %%
import pandas as pd

df = pd.read_csv('oil_consumption_per_cap.csv')
df.head(2)
# Out:
#      country   1965  1966   1967   1968   1969   1970   1971   1972   1973  \
# 0    Algeria  0.102  0.13  0.118  0.122  0.125  0.140  0.153  0.163  0.173
# 1  Argentina  0.990  1.01  1.020  1.020  1.050  0.923  0.969  0.954  0.939
#
#    ...   2007   2008   2009   2010   2011   2012   2013   2014   2015   2016
# 0  ...  0.376  0.402  0.419  0.411  0.430  0.448  0.458  0.452  0.488  0.465
# 1  ...  0.605  0.616  0.596  0.681  0.679  0.703  0.749  0.729  0.741  0.728
#
# [2 rows x 53 columns]

# %%
df.duplicated(subset=['1972', '1973'], keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 60    False
# 61    False
# 62     True
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df.loc[df.duplicated(subset=['1972', '1973'], keep=False)].head(2)
# Out:
#       country  1965  1966  1967  1968  1969  1970  1971  1972  1973  ...  \
# 4  Azerbaijan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6     Belarus   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     2007   2008   2009   2010   2011  2012   2013   2014   2015   2016
# 4  0.519  0.407  0.371  0.356  0.436  0.45  0.484  0.468  0.471  0.474
# 6  0.841  0.832  0.978  0.789  0.908  1.10  0.753  0.857  0.812  0.795
#
# [2 rows x 53 columns]

# %%
df.loc[df.duplicated(subset=['1972', '1973'], keep='first')].head(2) # first, last
# Out:
#        country  1965  1966  1967  1968  1969  1970  1971  1972  1973  ...  \
# 6      Belarus   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 30  Kazakhstan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      2007   2008   2009   2010   2011   2012   2013   2014   2015   2016
# 6   0.841  0.832  0.978  0.789  0.908  1.100  0.753  0.857  0.812  0.795
# 30  0.732  0.717  0.574  0.602  0.693  0.681  0.702  0.703  0.743  0.734
#
# [2 rows x 53 columns]

# %%
df.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %%
df['2013'].sum()
# Out:
# 92.88489999999999

# %%
df.sum(axis=0) # on columns
# Out:
# country    AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...
# 1965                                                 58.5859
# 1966                                                 60.3936
# 1967                                                 62.2033
# 1968                                                  65.489
# 1969                                                 68.5567
# 1970                                                 72.4774
# 1971                                                 72.8423
# 1972                                                 78.4649
# 1973                                                 81.0535
# 1974                                                 77.1468
# 1975                                                 73.6732
# 1976                                                 79.0424
# 1977                                                 80.1153
# 1978                                                 81.1106
# ...

# %%
df.sum(axis=1) # on rows
# Out:
# 0      15.4470
# 1      37.9510
# 2     102.2600
# 3      74.2630
# 4      23.5500
#         ...
# 60     74.9400
# 61    162.5100
# 62      9.8414
# 63     55.3070
# 64      4.9023
# Length: 65, dtype: float64

# %%
df.count()
# Out:
# country    65
# 1965       56
# 1966       56
# 1967       56
# 1968       56
# 1969       56
# 1970       56
# 1971       57
# 1972       57
# 1973       57
# 1974       57
# 1975       57
# 1976       57
# 1977       57
# 1978       57
# 1979       57
# 1980       57
# 1981       57
# 1982       57
# 1983       57
# 1984       57
# 1985       65
# 1986       65
# 1987       65
# 1988       65
# 1989       65
# 1990       65
# 1991       65
# 1992       65
# 1993       65
# 1994       65
# 1995       65
# 1996       65
# 1997       65
# 1998       65
# 1999       65
# 2000       65
# 2001       65
# 2002       65
# 2003       65
# 2004       65
# 2005       65
# 2006       65
# 2007       65
# 2008       65
# 2009       65
# 2010       65
# 2011       65
# 2012       65
# 2013       65
# 2014       65
# 2015       65
# 2016       65
# dtype: int64

# %%
df.cumsum(skipna=True)
# Out:
#                                               country     1965     1966  \
# 0                                             Algeria   0.1020   0.1300
# 1                                    AlgeriaArgentina   1.0920   1.1400
# 2                           AlgeriaArgentinaAustralia   2.4220   2.6900
# 3                    AlgeriaArgentinaAustraliaAustria   3.1830   3.5220
# 4          AlgeriaArgentinaAustraliaAustriaAzerbaijan      NaN      NaN
# ..                                                ...      ...      ...
# 60  AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...  54.8137  56.5193
# 61  AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...  57.5737  59.3893
# 62  AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...      NaN      NaN
# 63  AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...  58.5467  60.3103
# 64  AlgeriaArgentinaAustraliaAustriaAzerbaijanBang...  58.5859  60.3936
#
#        1967    1968     1969     1970     1971     1972     1973  ...  \
# ...

# %%
df['2013'].max(), df['2013'].idxmax()
# Out:
# (12.0, 47)

# %%
df['2013'].mean()
# Out:
# 1.4289984615384617

# %%
df.describe()
# Out:
#             1965       1966       1967       1968       1969       1970  \
# count  56.000000  56.000000  56.000000  56.000000  56.000000  56.000000
# mean    1.046177   1.078457   1.110773   1.169446   1.224227   1.294239
# std     1.663829   1.521913   1.415326   1.358183   1.323391   1.318698
# min     0.015200   0.019000   0.018300   0.019400   0.025400   0.034200
# 25%     0.219000   0.232000   0.211250   0.236750   0.253250   0.269750
# 50%     0.496500   0.543000   0.636000   0.687500   0.737000   0.837500
# 75%     1.340000   1.480000   1.570000   1.662500   1.762500   1.900000
# max    11.500000  10.100000   8.990000   8.010000   7.200000   6.520000
#
#             1971       1972       1973       1974  ...       2007       2008  \
# count  57.000000  57.000000  57.000000  57.000000  ...  65.000000  65.000000
# mean    1.277935   1.376577   1.421991   1.353453  ...   1.517988   1.512251
# std     1.257965   1.357090   1.320865   1.208123  ...   1.682956   1.708085
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df['2013'].pct_change(periods=10))
plt.show()

# %%
df.corr()
# Out:
#           1965      1966      1967      1968      1969      1970      1971  \
# 1965  1.000000  0.995186  0.983074  0.954634  0.919934  0.875623  0.857216
# 1966  0.995186  1.000000  0.995415  0.977363  0.951918  0.916527  0.900315
# 1967  0.983074  0.995415  1.000000  0.992533  0.974588  0.946559  0.932282
# 1968  0.954634  0.977363  0.992533  1.000000  0.992811  0.975509  0.962527
# 1969  0.919934  0.951918  0.974588  0.992811  1.000000  0.993890  0.986204
# 1970  0.875623  0.916527  0.946559  0.975509  0.993890  1.000000  0.996571
# 1971  0.857216  0.900315  0.932282  0.962527  0.986204  0.996571  1.000000
# 1972  0.832570  0.877364  0.913810  0.948521  0.973444  0.985825  0.989030
# 1973  0.794262  0.843443  0.884298  0.924505  0.956307  0.974924  0.984139
# 1974  0.773872  0.824792  0.869589  0.912588  0.944404  0.963683  0.973913
# 1975  0.694949  0.754880  0.807636  0.864120  0.908531  0.939912  0.953412
# ...
